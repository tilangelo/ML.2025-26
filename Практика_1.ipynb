# %% [markdown]
# # МЛ Практика 1
# ## Обзор занятий: Чем предстоит заниматься
# Цели сессии:
#
# 1. Ознакомление с основными понятиями машинного обучения и структурой практических занятий.
# 2. Представление доступных наборов данных для последующих упражнений.
# 3. Формирование списка участников и распределение ролей (при необходимости).
# 4. Практическое освоение методов описательного анализа данных.
# 5. Понимание типов данных и их важности в контексте машинного обучения.
# План занятий:
#
# 1. Введение и обзор целей курса.
# 2. Представление наборов данных.
# 3. Формирование списка студентов.
# 4. Совместный разбор выбранного набора данных с обсуждением вопросов.
# 5. Задача 1: Описание набора данных и определение типов данных.
# 6. Пример статистического разбора на основе wine.csv.
# 7. Обсуждение типов переменных и их определения по статистике.
# 8. Вопросы и ответы, обсуждение домашних заданий.

# %% [markdown]
# # Наборы данных по вариантам

# %% [markdown]
# Примеры наборов данных

# %% [markdown]
# 1. https://www.kaggle.com/datasets/nabeelqureshitiii/student-performance-dataset
# 2. https://www.kaggle.com/datasets/navjotkaushal/coffee-sales-dataset
# 3. https://www.kaggle.com/datasets/shamimhasan8/education-inequality-data
# 4. https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset
# 5. https://www.kaggle.com/datasets/navjotkaushal/employees-dataset
# 6. https://www.kaggle.com/datasets/abolfazlchanbary81/hearth
# 7. https://www.kaggle.com/datasets/uciml/student-alcohol-consumption
# 8. https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# 9. https://www.kaggle.com/datasets/lainguyn123/student-performance-factors
# 10. https://www.kaggle.com/datasets/benroshan/factors-affecting-campus-placement
# 11. https://www.kaggle.com/datasets/datascientistanna/customers-dataset

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = '/content/student-mat.csv' # Загрузка набора данных
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
# Вывод первых 5 строк
df.head()

# вывод 5 последних строк
#df.tail()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# Информация о наборе данных
df.info() # инфо о датасете название колонки, сколько не пропущенных, дефолтный тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB

# %%
# Статистический разбор
df.describe() # include=all (вывод включая категориальные)
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
# преобразование в категориальные
# df.columnName = df.columnName.astype('category')
# or
# df['column Name'] = df['column Name'].astype('category')

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или int (например метки класса)

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# school: 2 уникальных значений
# sex: 2 уникальных значений
# age: 8 уникальных значений
# address: 2 уникальных значений
# famsize: 2 уникальных значений
# Pstatus: 2 уникальных значений
# Medu: 5 уникальных значений
# Fedu: 5 уникальных значений
# Mjob: 5 уникальных значений
# Fjob: 5 уникальных значений
# reason: 4 уникальных значений
# guardian: 3 уникальных значений
# traveltime: 4 уникальных значений
# studytime: 4 уникальных значений
# failures: 4 уникальных значений
# schoolsup: 2 уникальных значений
# famsup: 2 уникальных значений
# paid: 2 уникальных значений
# activities: 2 уникальных значений
# nursery: 2 уникальных значений
# higher: 2 уникальных значений
# internet: 2 уникальных значений
# romantic: 2 уникальных значений
# famrel: 5 уникальных значений
# freetime: 5 уникальных значений
# goout: 5 уникальных значений
# Dalc: 5 уникальных значений
# Walc: 5 уникальных значений
# health: 5 уникальных значений
# absences: 34 уникальных значений
# G1: 17 уникальных значений
# G2: 17 уникальных значений
# G3: 18 уникальных значений

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %% [markdown]
# **Если одна переменная подходит под несколько типов**
# - Переменные studytime (1–4) и failures (0–4) лучше трактовать как категории с порядком (1 = мало, 4 = много)а не как непрерывное число. Переменные G1, G2, G3 — это оценки по 20-балльной шкале: их можно считать числовыми, так как арифметические операции (среднее, дисперсия) имеют смысл.

# %%
#номинальные
nominal_vars = [
    "school", "sex", "address", "famsize", "Pstatus", "Mjob", "Fjob",
    "reason", "guardian", "schoolsup", "famsup", "paid", "activities",
    "nursery", "higher", "internet", "romantic"
]
#порядковые
ordinal_vars = [
    "Medu", "Fedu", "traveltime", "studytime", "failures",
    "famrel", "freetime", "goout", "Dalc", "Walc", "health"
]
#числовые
numeric_vars = [
    "age", "absences", "G1", "G2", "G3"
]

# %%
# ---- 2. Статистика для числовых переменных ----
print("=== Статистика для числовых переменных ===")
print(df[numeric_vars].describe())

# ---- 3. Статистика для категориальных переменных ----
print("\n=== Статистика для номинальных переменных ===")
for col in nominal_vars:
    print(f"\n{col}:")
    print(df[col].value_counts())
# Out:
# === Статистика для числовых переменных ===
#               age    absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    5.708861   10.908861   10.713924   10.415190
# std      1.276043    8.003096    3.319195    3.761505    4.581443
# min     15.000000    0.000000    3.000000    0.000000    0.000000
# 25%     16.000000    0.000000    8.000000    9.000000    8.000000
# 50%     17.000000    4.000000   11.000000   11.000000   11.000000
# 75%     18.000000    8.000000   13.000000   13.000000   14.000000
# max     22.000000   75.000000   19.000000   19.000000   20.000000
#
# === Статистика для номинальных переменных ===
#
# school:
# school
# GP    349
# MS     46
# Name: count, dtype: int64
#
# sex:
# sex
# F    208
# M    187
# Name: count, dtype: int64
#
# address:
# address
# U    307
# R     88
# Name: count, dtype: int64
#
# famsize:
# famsize
# GT3    281
# LE3    114
# Name: count, dtype: int64
#
# Pstatus:
# Pstatus
# T    354
# A     41
# Name: count, dtype: int64
#
# Mjob:
# Mjob
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: count, dtype: int64
#
# Fjob:
# Fjob
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: count, dtype: int64
#
# reason:
# reason
# course        145
# home          109
# reputation    105
# other          36
# Name: count, dtype: int64
#
# guardian:
# guardian
# mother    273
# father     90
# other      32
# Name: count, dtype: int64
#
# schoolsup:
# schoolsup
# no     344
# yes     51
# Name: count, dtype: int64
#
# famsup:
# famsup
# yes    242
# no     153
# Name: count, dtype: int64
#
# paid:
# paid
# no     214
# yes    181
# Name: count, dtype: int64
#
# activities:
# activities
# yes    201
# no     194
# Name: count, dtype: int64
#
# nursery:
# nursery
# yes    314
# no      81
# Name: count, dtype: int64
#
# higher:
# higher
# yes    375
# no      20
# Name: count, dtype: int64
#
# internet:
# internet
# yes    329
# no      66
# Name: count, dtype: int64
#
# romantic:
# romantic
# no     263
# yes    132
# Name: count, dtype: int64

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовых переменных:**

# %%
sns.histplot(df['G1'], kde=True)
plt.title('распределение оценок за первый грейд')
plt.xlabel('G1')
plt.ylabel('Частота')
plt.show()

# ниже код для оптимизации вывода всех числовых переменных
#num_cols = df.select_dtypes(include='float').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.histplot(df[col], kde=True, ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него?
# - **Ответ**: Большая часть оценок сосредоточена в промежутке от 7 до 12, это говорит о том, что распределение оценок первого грейда не является нормальным
# - Концентрация большинства значений
# - **Ответ**: большинство значений сконцентрированно от 8 до 12 баллов.
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
# - **Ответ**: Распределение оценок G3 в зависимости от пола (sex).
# Распределение пропусков (absences) в зависимости от статуса отношений (romantic).
# Распределение алкоголя (Walc) в зависимости от наличия интернета (internet).
#
# p.s. 3-5 самых показательных примеров.

# %%
#распределение финальных оценок по полу
sns.histplot(data=df, x="G3", hue="sex", kde=True, element="step")
plt.title("Распределение итоговых оценок по полу")
plt.show()

#распределение пропусков по статусу романтических отношений
sns.histplot(data=df, x="absences", hue="romantic", kde=False, bins=20)
plt.title("Пропуски по статусу отношений")
plt.show()

#распределение времени на учебу в зависимости от доступа к интернету
sns.histplot(data=df, x="studytime", hue="internet", multiple="dodge")
plt.title("Время на учебу в зависимости от интернета")
plt.show()

# %% [markdown]
# 2. **Столбчатая диаграмма для категориальной переменной `Class`:**

# %%
sns.countplot(x='freetime', data=df)
plt.title('Распределение freetime')
plt.xlabel('freetime')
plt.ylabel('Количество')
plt.show()

# ниже код для оптимизации вывода всех категориальных переменных
#num_cols = df.select_dtypes(include='category').columns # или object
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.histplot(df[col], kde=True, ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная?
# - **Ответ**: 1(Оценки). распределение не нормальное, большинство значений сосредоточено между 8–15 баллами, с пиком около 10–12, очень низкие и очень высокие оценки встречаются редко. 2(Пропуски). распределение сильно скошено вправо (правый хвост), большинство студентов имеет от 0 до 10 пропусков, но есть несколько выбросов (40–70). 3(Время учебы). распределение показывает, что наличие интернета не противоречит времени учёбы.
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
# - **Ответ**: у мальчиков чаще встречаются высокие значения Walc (3–5), у девочек — низкие.

# %%
sns.histplot(data=df, x="Walc", hue="sex", multiple="dodge")
plt.title("Употребление алкоголя по выходным в зависимости от пола")
plt.show()

# %% [markdown]
# **Боксплот для числовой переменной:**

# %%
sns.boxplot(x=df['health'])
plt.title('Boxplot health')
plt.xlabel('Health')
plt.show()

#num_cols = df.select_dtypes(include='float').columns # если есть int чиловая переменная либо + ['col1', 'col2'], либо такие колонки преобразовать во flaot
#fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

#for ax, col in zip(axes, num_cols):
#    sns.boxplot(df[col], ax=ax)
#    ax.set_title(f'Распределение {col}')
#    ax.set_xlabel(col)
#    ax.set_ylabel('Частота')

#plt.tight_layout()
#plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Есть ли выбросы?
# - **Ответ**: выбросов нет, медиана на 4.
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане
# - **Ответ**: медиана у девушек немного ниже, чем у юношей, разброс значений примерно одинаковый, экстремальные низкие оценки встречаются у обоих полов.

# %%
sns.boxplot(x="sex", y="G3", data=df)
plt.title("Boxplot итоговых оценок по полу")
plt.show()

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
corr_matrix = df.select_dtypes(include=['int64', 'float64']).corr()

# Визуализация
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Корреляционная матрица (числовые переменные)")
plt.show()

# %% [markdown]
# **если ValueError Я просто взял только числовые переменные**

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('colName', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют?
# - **Ответ**: переменные age, health, freetime, практически не коррелируют с успеваемостью
# - Какие переменные имеют сильную положительную корреляцию?
# - **Ответ**: Наибольшая положительная корреляция наблюдается между оценками G1, G2 и G3. Логично, тк промежуточные результаты отражают итоговую успеваемость.
# - Какие переменные имеют сильную слабую корреляцию?
# - **Ответ**: выявлена между количеством пропусков (absences) и итоговой оценкой (G3), чем больше пропусков, тем хуже результат.
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7
